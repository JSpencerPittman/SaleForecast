# %% [markdown]
# ### Load the Data

# %%
from DataPool.Aggregate import Aggregate

agg = Aggregate()
agg.aggregate_training_set()
# Out:
# Started
# Searching for previously formatted datasets...
# Previously formatted dataset found...
# Loading contents...
# Contents loaded...
# Complete

# %%
from Visualization.FeatureSummary import explain_data

explain_data(agg.train)

# %%
agg.train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300089 entries, 0 to 300088
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             300089 non-null  datetime64[ns]
#  1   store_nbr        300089 non-null  int64
#  2   family           300089 non-null  object
#  3   sales            300089 non-null  float64
#  4   onpromotion      300089 non-null  int64
#  5   dcoilwtico       207246 non-null  float64
#  6   city             300089 non-null  category
#  7   state            300089 non-null  category
#  8   store_type       300089 non-null  category
#  9   cluster          300089 non-null  uint8
#  10  transactions     300089 non-null  float64
#  11  holi_importance  300089 non-null  int64
#  12  holi_type        300089 non-null  category
# dtypes: category(4), datetime64[ns](1), float64(3), int64(3), object(1), uint8(1)
# memory usage: 19.7+ MB

# %%
agg.train.city.value_counts()
# Out:
# Quito            100032
# Guayaquil         44458
# Cuenca            17177
# Santo Domingo     16502
# Manta             11114
# Machala           11114
# Latacunga         11114
# Ambato            10778
# Ibarra             5726
# Playas             5726
# Quevedo            5726
# Cayambe            5726
# Guaranda           5725
# Babahoyo           5725
# Puyo               5725
# Loja               5389
# El Carmen          5389
# Daule              5389
# Riobamba           5389
# Libertad           5389
# Esmeraldas         5388
# Salinas            5388
# Name: city, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %%
focus = agg.train.city.value_counts()

# %%
plt.barh(focus.index, focus.values, color=corr_colors)
plt.show()

# %%
def category_distribution(feature, varying_color = False, bar_cmap = 'rainbow', **kwargs):
    counts = feature.value_counts()
    fig, ax = plt.subplots()
    bar_colors = plt.get_cmap(bar_cmap)(counts.values / np.max(counts.values))
    ax.set_ylabel(feature.name.capitalize())
    ax.set_xlabel("Occurences")
    ax.set_title("Distribution of {}".format(feature.name))
    ax.barh(counts.index, counts.values, color=bar_colors, **kwargs)
    plt.show()

# %%
from Distributions import graph_category_distribution

graph_category_distribution(agg.train.city)

# %%
corr_colors = plt.get_cmap('rainbow')(focus.values / np.max(focus.values))

# %%
import matplotlib.cm as cm

my_cmap = plt.get_cmap("rainbow")
my_cmap([0.2,0.5])
# Out:
# array([[0.1       , 0.58778525, 0.95105652, 1.        ],
#        [0.50392157, 0.99998103, 0.70492555, 1.        ]])

# %%
plt.get_cmap('rainbow')([0.2,0.5])
# Out:
# array([[0.1       , 0.58778525, 0.95105652, 1.        ],
#        [0.50392157, 0.99998103, 0.70492555, 1.        ]])

# %%
focus.name.capitalize()
# Out:
# 'City'
