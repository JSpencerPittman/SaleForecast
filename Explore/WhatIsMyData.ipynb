# %% [markdown]
# ### Load the Data

# %%
from DataPool.Aggregate import Aggregate

agg = Aggregate()
agg.aggregate_training_set()
# Out:
# Started
# Searching for previously formatted datasets...
# Previously formatted dataset found...
# Loading contents...
# Contents loaded...
# Complete

# %%
import matplotlib.pyplot as plt
case_study = agg.train.store_nbr

# %%
plt.hist(case_study.values)
plt.show()

# %%
from Distributions import graph_category_distribution
graph_category_distribution(agg.train.onpromotion)

# %%
agg.train.onpromotion
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 300084     5
# 300085     0
# 300086     7
# 300087     0
# 300088    11
# Name: onpromotion, Length: 300089, dtype: int64
